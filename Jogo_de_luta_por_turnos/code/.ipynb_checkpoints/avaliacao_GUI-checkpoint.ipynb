# %%
from tkinter import *
from PIL import ImageTk, Image
from random import randint
import tkinter.font as tkFont

root = Tk()
root.title('Jogo de Luta')
fundo = '#ffaec9'
rosa = '#ffccdd'
root.configure(bg = fundo)

fontStyle = tkFont.Font(family="Lucida Grande", size=20)
fontStyle2 = tkFont.Font(family="Lucida Grande", size=15)

# Upload das imagens
personagem_principal = ImageTk.PhotoImage(Image.open("imagens/personagem_principal.png"))
personagem_agilidade = ImageTk.PhotoImage(Image.open("imagens/personagem_agilidade.png"))
personagem_balanceado = ImageTk.PhotoImage(Image.open("imagens/personagem_balanceado.png"))
personagem_escudo = ImageTk.PhotoImage(Image.open("imagens/personagem_escudo.png"))
personagem_sorte = ImageTk.PhotoImage(Image.open("imagens/personagem_sorte.png"))
vida_100_label = ImageTk.PhotoImage(Image.open("imagens/vida_100.png"))
vida_90_label = ImageTk.PhotoImage(Image.open("imagens/vida_90.png"))
vida_80_label = ImageTk.PhotoImage(Image.open("imagens/vida_80.png"))
vida_70_label = ImageTk.PhotoImage(Image.open("imagens/vida_70.png"))
vida_60_label = ImageTk.PhotoImage(Image.open("imagens/vida_60.png"))
vida_50_label = ImageTk.PhotoImage(Image.open("imagens/vida_50.png"))
vida_40_label = ImageTk.PhotoImage(Image.open("imagens/vida_40.png"))
vida_30_label = ImageTk.PhotoImage(Image.open("imagens/vida_30.png"))
vida_20_label = ImageTk.PhotoImage(Image.open("imagens/vida_20.png"))
vida_10_label = ImageTk.PhotoImage(Image.open("imagens/vida_10.png"))
vida_0_label = ImageTk.PhotoImage(Image.open("imagens/vida_base.png"))
vazio_label = ImageTk.PhotoImage(Image.open("imagens/vazio.png"))


def adversario2(adversario1):
    global adversario
    adversario = adversario1
    

frame_instrucoes = LabelFrame(root, text='Instruções', font=fontStyle2, bg=rosa, bd=4, padx=10, pady=10)
frame_instrucoes.grid(padx=40, pady=40, row=0, column=0, columnspan=3)
Label(frame_instrucoes, bg=rosa, font=fontStyle2, text='Cada jogador terá uma ação por turno, escolhendo entre uma manobra arriscada ou conservadora.\nNo caso do movimento arriscado, seu poder de Ataque é dobrado apenas neste instante\nNo caso do movimento conservador, seu poder de Defesa é temporariamente dobrado.\nTem uma chance de causar 10 de dano extra (crítico) conforme o seu nível de Sorte.\nÉ feito o sorteio de um número aleatório entre 1 e 20 e se o parâmetro de Sorte for maior do que o valor sorteado,\nentão o Jogador 2 sofrerá esse ataque crítico, que é independente do que aconteceu no item anterior.').grid(row=0, column=0)
    
    
frame_atributos = LabelFrame(root, text='Escolha seus atributos', font=fontStyle, bg=rosa, bd=4, padx=5, pady=5)
frame_atributos.grid(padx=10, pady=10, row=1, column=0)
Label(frame_atributos, font=fontStyle2, bg=rosa, text='Escolha seus atributos.\nVocê possui 30 pontos para dividir entre ataque, defesa e sorte.\n*Um atributo precisa ter ao menos 1 ponto e no máximo 20').grid(row=0, column=0, columnspan=3)
Label(frame_atributos, font=fontStyle2, bg=rosa, text='Ataque').grid(row=1, column=0)
entryAtaque = Entry(frame_atributos, width=4)
entryAtaque.grid(row=1, column=1)
Label(frame_atributos, font=fontStyle2, bg=rosa, text='Defesa').grid(row=2, column=0)
entryDefesa = Entry(frame_atributos, width=4)
entryDefesa.grid(row=2, column=1)
Label(frame_atributos, font=fontStyle2, bg=rosa, text='Sorte').grid(row=3, column=0)
entrySorte = Entry(frame_atributos, width=4)
entrySorte.grid(row=3, column=1)


frame_adversario = LabelFrame(root, text='Escolha seu adversario', font=fontStyle, bg=rosa, bd=4, padx=5, pady=5)
frame_adversario.grid(padx=5, pady=5, row=1, column=1)
adversario1 = IntVar()
adversario1.set(' ')
Radiobutton(frame_adversario, font=fontStyle2, text='Ofensivo', variable=adversario1, value=0, bg=rosa, command=lambda: adversario2(adversario1.get())).grid(row=5, column=0)
Radiobutton(frame_adversario, font=fontStyle2, text='Balanceado', variable=adversario1, value=1, bg=rosa, command=lambda: adversario2(adversario1.get())).grid(row=6, column=0)
Radiobutton(frame_adversario, font=fontStyle2, text='Defensivo', variable=adversario1, value=2, bg=rosa, command=lambda: adversario2(adversario1.get())).grid(row=7, column=0)
Radiobutton(frame_adversario, font=fontStyle2, text='Sortudo', variable=adversario1, value=3, bg=rosa, command=lambda: adversario2(adversario1.get())).grid(row=8, column=0)


jogador_1 = [[100]]
jogador_2 = [[100]]
oponente_0 = [15, 5, 10]
oponente_1 = [10, 10, 10]
oponente_2 = [5, 15, 10]
oponente_3 = [5, 5, 20]
botao = Button(root, font=fontStyle, text="Iniciar luta", command=lambda: apaga_tudo(ataque_1=int(entryAtaque.get()), defesa_1=int(entryDefesa.get()), sorte_1=int(entrySorte.get()), oponente=int(adversario)))
botao.grid(row=10, column=0)

def apaga_tudo(ataque_1, defesa_1, sorte_1, oponente):
    

    for ele in root.winfo_children():
        ele.destroy()
    vida_100 = Label(image=vida_100_label, borderwidth=0).grid(row=2, column=2)
    vida_100 = Label(image=vida_100_label, borderwidth=0).grid(row=2, column=3)
    principal_label = Label(image=personagem_principal, borderwidth=0)
    principal_label.grid(row=3, column=2)
    
    jogador_1.insert(0, [ataque_1, defesa_1, sorte_1])
    if oponente == 0:
        jogador_2.insert(0, oponente_0)
        agilidade = Label(image=personagem_agilidade, borderwidth=0)
        agilidade.grid(row=3, column=3)
    elif oponente == 1:
        jogador_2.insert(0, oponente_1)
        balanceado = Label(image=personagem_balanceado, borderwidth=0)
        balanceado.grid(row=3, column=3)
    elif oponente == 2:
        jogador_2.insert(0, oponente_2)
        escudo = Label(image=personagem_escudo, borderwidth=0)
        escudo.grid(row=3, column=3)
    else:
        jogador_2.insert(0, oponente_3)
        sorte = Label(image=personagem_sorte, borderwidth=0)
        sorte.grid(row=3, column=3)
    print(f'atributos do jogador 1 : {jogador_1}')
    print(f'atributos do jogador 2 : {jogador_2}')
    defesa_jogador_1 = defesa_1
    defesa_jogador_2 = jogador_2[0][1]
    

    #while jogador_1[1][0] > 0 and jogador_2[1][0] > 0:
        jogador = 0
        contador = 0
        contador += 1
        Label(root, text='{}\n{} ROUND {} {}\n{}'.format(29 * '*', 8 * '*', contador, 8 * '*', 29 * '*'), bg=fundo, font = fontStyle).grid(row=0, column=2, columnspan=2)
        Label(root, text=f'\n\nSaúde atual do Jogador 1: {str(jogador_1[1][0])}\t\tSaúde atual do Jogador 2: {str(jogador_2[1][0])}', bg = fundo, font = fontStyle2).grid(row=1, column=2, columnspan=2)
        # Esse if serve pra poder fazer a interpolação entre 2 números
        if jogador == 1:
            jogador = 2
        else:
            jogador = 1
            
        
        atacar_1 = Button(root, text="Atacar", borderwidth=1, bg=rosa, command=lambda: ataque_jogador_1(jogador_1[0][0], defesa_jogador_2)).grid(row=4, column=0)
        defender_1 = Button(root, text="Defender", borderwidth=1, bg=rosa).grid(row=4, column=1)
        
        
        print(f'defesa do jogador 1: {defesa_jogador_1}')
        print(f'defesa do jogador 2: {defesa_jogador_2}')
        
    
        def ataque_jogador_1(dano, defesa):
            valor_ataque = (dano * 2 - defesa)
            if valor_ataque > defesa:
                jogador_2[1][0] -= valor_ataque
            defesa = jogador_2[0][1]
            if jogador_1[0][2] > randint(1, 20):
                jogador_2[1][0] -= 10
                print('jogador 2 recebeu crítico')
            print(f'atributos do jogador 2 : {jogador_2}') 
                
    

    print(f'atributos do jogador 1 : {jogador_1}')
    print(f'atributos do jogador 2 : {jogador_2}')
        
#     def defesa_jogador_1(defesa):
#         defesa_1 = jogador_1[0][1] * 2
#         if randint(1, 20) > jogador_1[0][2]:
#             jogador_2[1][0] -= 10
#             print('jogador 2 recebeu crítico')
#         print(jogador_1, jogador_2)
#         jogada_jogador_2()

#     def jogada_jogador_2(defesa_1=jogador_1[0][1]):
#         if randint(0, 1) == 0:
#             jogador_1[1][0] -= (jogador_2[0][0] * 2 - defesa_1)
#             defesa_1 = jogador_1[0][1]
#             print('atacou')
#         else:
#             defesa2 = jogador_2[0][1] * 2
#             print('defendeu')
#         if randint(1, 20) > jogador_2[0][2]:
#             jogador_1[1][0] -= 10
#             print('jogador 1 recebeu crítico')
#         print(jogador_1, jogador_2)
        
        


#     if jogador == 1:  # Usando a variável jogador para alternar as jogadas
#         if defesa_1 == (jogador_1[1][1] * 2):  # Resetando a defesa para não acumular caso nenhum dos dois tenha escolhido ataque
#             defesa_1 = jogador_1[1][1]

#         if manobra == 1:
#             if (ataque_1 * 2) > defesa_2:  # Checa se terá dano para iniciar a função de ataque
#                 ataque_jogador_1(ataque_1 * 2 - defesa_2)

#             if jogador_1[1][2] > randint(1, 20):  # Checa se haverá um dano crítico ou não
#                 print('O jogador 2 recebeu um dano crítico')
#                 jogador_2[0][0] -= 10
#         elif manobra == 2:
#             defesa_1 *= 2
#             print(f'Sua defesa aumentou para {defesa_1}')
#             if jogador_1[1][2] > randint(1, 20):  # Precisei checar o crítico aqui novamente
#                 print('O jogador 2 recebeu um dano crítico')
#                 jogador_2[0][0] -= 10
#         else:
#             print('ERRO. Escolha inválida.')  # Colocando um while nesse bloco, dá pra fazer essa escolha errada dar uma nova chance
#                                               # De escolha, mas eu não o fiz.


#     # Aqui o código se repete para o jogador 2
#     else:
#         if defesa_2 == (jogador_2[1][1] * 2):
#             defesa_2 = jogador_2[1][1]
#         if manobra == 1:
#             if (ataque_2 * 2) > defesa_1:
#                 ataque_jogador_2(ataque_2 * 2 - defesa_1)
#             if jogador_2[1][2] > randint(1, 20):
#                 print('O jogador 1 recebeu um dano crítico')
#                 jogador_1[0][0] -= 10

#         elif manobra == 2:
#             defesa_2 *= 2
#             print(f'Sua defesa aumentou para {defesa_2}')
#             if jogador_2[1][2] > randint(1, 20):
#                 print('O jogador 1 recebeu um dano crítico')
#                 jogador_1[0][0] -= 10
#         else:
#             print('ERRO. Escolha inválida.')







        



root.mainloop()
# Out:
# atributos do jogador 1 : [[10, 10, 10], [100]]
# atributos do jogador 2 : [[10, 10, 10], [100]]
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# defesa do jogador 1: 10
# defesa do jogador 2: 10
# ...
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 1170, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\inspect.py", line 705, in getsourcefile
#     if os.path.exists(filename):
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 2047, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 1436, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 1336, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 1193, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 1148, in format_exception_as_a_whole
#     records = self.get_records(etb, number_of_lines_of_context, tb_offset)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 1185, in get_records
#     traceback.print_exc(file=self.ostream)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\traceback.py", line 163, in print_exc
#     print_exception(*sys.exc_info(), limit=limit, file=file, chain=chain)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\traceback.py", line 103, in print_exception
#     for line in TracebackException(
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\traceback.py", line 509, in __init__
#     self.stack = StackSummary.extract(
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\traceback.py", line 366, in extract
#     f.line
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\traceback.py", line 288, in line
#     self._line = linecache.getline(self.filename, self.lineno).strip()
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\linecache.py", line 16, in getline
#     lines = getlines(filename, module_globals)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\linecache.py", line 47, in getlines
#     return updatecache(filename, module_globals)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\linecache.py", line 136, in updatecache
#     with tokenize.open(fullname) as fp:
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\tokenize.py", line 392, in open
#     buffer = _builtin_open(filename, 'rb')
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 3338, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 3435, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 2060, in showtraceback
#     print('\n' + self.get_exception_only(), file=sys.stderr)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 2005, in get_exception_only
#     msg = traceback.format_exception_only(etype, value)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\traceback.py", line 140, in format_exception_only
#     return list(TracebackException(etype, value, None).format_exception_only())
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\traceback.py", line 524, in __init__
#     self._load_lines()
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\traceback.py", line 536, in _load_lines
#     self.__context__._load_lines()
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\traceback.py", line 534, in _load_lines
#     frame.line
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\traceback.py", line 288, in line
#     self._line = linecache.getline(self.filename, self.lineno).strip()
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\linecache.py", line 16, in getline
#     lines = getlines(filename, module_globals)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\linecache.py", line 47, in getlines
#     return updatecache(filename, module_globals)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\linecache.py", line 136, in updatecache
#     with tokenize.open(fullname) as fp:
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\tokenize.py", line 392, in open
#     buffer = _builtin_open(filename, 'rb')
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 1170, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\inspect.py", line 1465, in getframeinfo
#     lines, lnum = findsource(frame)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 182, in findsource
#     lines = linecache.getlines(file, globals_dict)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\linecache.py", line 47, in getlines
#     return updatecache(filename, module_globals)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\linecache.py", line 136, in updatecache
#     with tokenize.open(fullname) as fp:
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\tokenize.py", line 392, in open
#     buffer = _builtin_open(filename, 'rb')
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 2047, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 1436, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 1336, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 1193, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 1148, in format_exception_as_a_whole
#     records = self.get_records(etb, number_of_lines_of_context, tb_offset)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 1185, in get_records
#     traceback.print_exc(file=self.ostream)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\traceback.py", line 163, in print_exc
#     print_exception(*sys.exc_info(), limit=limit, file=file, chain=chain)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\traceback.py", line 103, in print_exception
#     for line in TracebackException(
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\traceback.py", line 509, in __init__
#     self.stack = StackSummary.extract(
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\traceback.py", line 366, in extract
#     f.line
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\traceback.py", line 288, in line
#     self._line = linecache.getline(self.filename, self.lineno).strip()
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\linecache.py", line 16, in getline
#     lines = getlines(filename, module_globals)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\linecache.py", line 47, in getlines
#     return updatecache(filename, module_globals)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\linecache.py", line 136, in updatecache
#     with tokenize.open(fullname) as fp:
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\tokenize.py", line 392, in open
#     buffer = _builtin_open(filename, 'rb')
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 2923, in _run_cell
#     return runner(coro)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 3146, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     self.showtraceback()
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 2060, in showtraceback
#     print('\n' + self.get_exception_only(), file=sys.stderr)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 2005, in get_exception_only
#     msg = traceback.format_exception_only(etype, value)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\traceback.py", line 140, in format_exception_only
#     return list(TracebackException(etype, value, None).format_exception_only())
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\traceback.py", line 524, in __init__
#     self._load_lines()
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\traceback.py", line 536, in _load_lines
#     self.__context__._load_lines()
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\traceback.py", line 534, in _load_lines
#     frame.line
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\traceback.py", line 288, in line
#     self._line = linecache.getline(self.filename, self.lineno).strip()
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\linecache.py", line 16, in getline
#     lines = getlines(filename, module_globals)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\linecache.py", line 47, in getlines
#     return updatecache(filename, module_globals)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\linecache.py", line 136, in updatecache
#     with tokenize.open(fullname) as fp:
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\tokenize.py", line 392, in open
#     buffer = _builtin_open(filename, 'rb')
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 1170, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\inspect.py", line 1465, in getframeinfo
#     lines, lnum = findsource(frame)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\ultratb.py", line 182, in findsource
#     lines = linecache.getlines(file, globals_dict)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\linecache.py", line 47, in getlines
#     return updatecache(filename, module_globals)
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\linecache.py", line 137, in updatecache
#     lines = fp.readlines()
#   File "c:\users\rodrigo\appdata\local\programs\python\python38-32\lib\codecs.py", line 319, in decode
#     def decode(self, input, final=False):
# KeyboardInterrupt
